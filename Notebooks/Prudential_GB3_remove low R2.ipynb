# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('../Data/train.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59381 entries, 0 to 59380
# Columns: 128 entries, Id to Response
# dtypes: float64(18), int64(109), object(1)
# memory usage: 58.0+ MB

# %%
pd.set_option('display.max_columns', None)
data.head(3)
# Out:
#    Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0   2               1             D3              10        0.076923
# 1   5               1             A1              26        0.076923
# 2   6               1             E1              26        0.076923
#
#    Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  \
# 0               2               1               1  0.641791  0.581818
# 1               2               3               1  0.059701  0.600000
# 2               2               3               1  0.029851  0.745455
#
#          Wt       BMI  Employment_Info_1  Employment_Info_2  \
# 0  0.148536  0.323008              0.028                 12
# 1  0.131799  0.272288              0.000                  1
# 2  0.288703  0.428780              0.030                  9
#
#    Employment_Info_3  Employment_Info_4  Employment_Info_5  Employment_Info_6  \
# 0                  1                0.0                  3                NaN
# ...

# %%
train_data=pd.get_dummies(data)

# %%
train_data.drop("Id", axis=1, inplace=True)
train_data.head(2)
# Out:
#    Product_Info_1  Product_Info_3  Product_Info_4  Product_Info_5  \
# 0               1              10        0.076923               2
# 1               1              26        0.076923               2
#
#    Product_Info_6  Product_Info_7   Ins_Age        Ht        Wt       BMI  \
# 0               1               1  0.641791  0.581818  0.148536  0.323008
# 1               3               1  0.059701  0.600000  0.131799  0.272288
#
#    Employment_Info_1  Employment_Info_2  Employment_Info_3  Employment_Info_4  \
# 0              0.028                 12                  1                0.0
# 1              0.000                  1                  3                0.0
#
#    Employment_Info_5  Employment_Info_6  InsuredInfo_1  InsuredInfo_2  \
# 0                  3                NaN              1              2
# 1                  2             0.0018              1              2
#
#    InsuredInfo_3  InsuredInfo_4  InsuredInfo_5  InsuredInfo_6  InsuredInfo_7  \
# ...

# %% [markdown]
# ## Null Values

# %%
pd.set_option('display.max_rows', None)
train_data.isnull().sum()
# Out:
# Product_Info_1             0
# Product_Info_3             0
# Product_Info_4             0
# Product_Info_5             0
# Product_Info_6             0
# Product_Info_7             0
# Ins_Age                    0
# Ht                         0
# Wt                         0
# BMI                        0
# Employment_Info_1         19
# Employment_Info_2          0
# Employment_Info_3          0
# Employment_Info_4       6779
# Employment_Info_5          0
# Employment_Info_6      10854
# InsuredInfo_1              0
# InsuredInfo_2              0
# InsuredInfo_3              0
# InsuredInfo_4              0
# InsuredInfo_5              0
# InsuredInfo_6              0
# InsuredInfo_7              0
# Insurance_History_1        0
# Insurance_History_2        0
# Insurance_History_3        0
# Insurance_History_4        0
# Insurance_History_5    25396
# Insurance_History_7        0
# Insurance_History_8        0
# Insurance_History_9        0
# Family_Hist_1              0
# ...

# %% [markdown]
# ## new dataframe to fill NaN's with 0's

# %%
Z_train=train_data.copy()

# %%
Z_train.fillna(0, inplace=True)

# %%
Z_train.isnull().sum()[:3]
# Out:
# Product_Info_1    0
# Product_Info_3    0
# Product_Info_4    0
# dtype: int64

# %% [markdown]
# ## Look at R2 and drop low values

# %%
corr_matrix=Z_train.corr()
corr_matrix['Response'].sort_values(ascending=False)
# Out:
# Response               1.000000
# Medical_History_23     0.286584
# Medical_History_4      0.239896
# Medical_History_39     0.220176
# Product_Info_4         0.202434
# Medical_History_6      0.159230
# Product_Info_2_D4      0.144096
# Family_Hist_2          0.141689
# Medical_History_13     0.134863
# Medical_History_40     0.131519
# InsuredInfo_6          0.130476
# Medical_History_33     0.113112
# Family_Hist_4          0.108676
# Product_Info_2_A6      0.092151
# Medical_History_27     0.084595
# InsuredInfo_1          0.083729
# Medical_History_1      0.081312
# Employment_Info_2      0.078857
# Medical_History_29     0.078089
# Medical_History_20     0.077327
# Medical_History_17     0.073633
# Family_Hist_1          0.072107
# Medical_History_9      0.067236
# Employment_Info_5      0.054673
# Product_Info_2_B2      0.050418
# Medical_History_22     0.047906
# Medical_History_31     0.046912
# Product_Info_2_A5      0.046351
# Medical_History_34     0.044429
# ...

# %%
## Drop less than 3% correlation

reduced_train=Z_train.drop(['Medical_History_7', 'InsuredInfo_4', 'Medical_History_3', 'Product_Info_2_A3',
                            'Employment_Info_6', 'Product_Info_2_A4', 'Insurance_History_5', 'Medical_History_2',
                            'Product_Info_1', 'Product_Info_2_C4', 'Medical_Keyword_39', 'Medical_Keyword_6',
                            'Medical_Keyword_20', 'Insurance_History_8', 'Insurance_History_3', 'Medical_Keyword_45',
                            'Medical_Keyword_8', 'Insurance_History_1', 'Medical_History_26', 'Insurance_History_4',
                            'Medical_History_25', 'Product_Info_2_C3', 'Medical_History_36', 'Product_Info_5',
                            'Medical_History_32', 'Product_Info_7', 'Insurance_History_9', 'Medical_Keyword_17',
                            'Insurance_History_7', 'Medical_Keyword_32', 'Medical_Keyword_41', 'Product_Info_2_B1',
                            'InsuredInfo_3', 'Product_Info_2_C2', 'Medical_Keyword_26', 'Medical_Keyword_2',
                            'Product_Info_2_A2', 'Product_Info_2_C1', 'Medical_Keyword_5', 'Medical_Keyword_29',
                            'Medical_Keyword_44', 'Medical_Keyword_7', 'Medical_Keyword_14', 'Employment_Info_4',
                            'Medical_Keyword_21', 'Medical_Keyword_30', 'Medical_Keyword_11', 'Medical_Keyword_28',
                            'Product_Info_2_D3', 'Medical_History_24'], axis=1)

# %% [markdown]
# ## Engineer new columns

# %%
reduced_train.head(1)
# Out:
#    Product_Info_3  Product_Info_4  Product_Info_6   Ins_Age        Ht  \
# 0              10        0.076923               1  0.641791  0.581818
#
#          Wt       BMI  Employment_Info_1  Employment_Info_2  \
# 0  0.148536  0.323008              0.028                 12
#
#    Employment_Info_3  Employment_Info_5  InsuredInfo_1  InsuredInfo_2  \
# 0                  1                  3              1              2
#
#    InsuredInfo_5  InsuredInfo_6  InsuredInfo_7  Insurance_History_2  \
# 0              1              2              1                    1
#
#    Family_Hist_1  Family_Hist_2  Family_Hist_3  Family_Hist_4  Family_Hist_5  \
# 0              2            0.0       0.598039            0.0       0.526786
#
#    Medical_History_1  Medical_History_4  Medical_History_5  Medical_History_6  \
# 0                4.0                  1                  1                  3
#
#    Medical_History_8  Medical_History_9  Medical_History_10  \
# ...

# %%
## Product total
reduced_train['Product_Total']=(reduced_train['Product_Info_3']+reduced_train["Product_Info_4"]+reduced_train["Product_Info_6"])

# %%
##  Employment Total
reduced_train['Employment_Total']=(reduced_train['Employment_Info_1']+reduced_train['Employment_Info_2']+reduced_train['Employment_Info_3']
                            +reduced_train['Employment_Info_5'])

# %%
##  Insured Total
reduced_train['Insured_Total']=(reduced_train['InsuredInfo_1']+reduced_train['InsuredInfo_2']+reduced_train['InsuredInfo_5']+reduced_train['InsuredInfo_6']+reduced_train['InsuredInfo_7'])

# %%
## Family Total
reduced_train['Family_Hist_Total']=(reduced_train['Family_Hist_1']+reduced_train['Family_Hist_2']+reduced_train['Family_Hist_3']+
                             reduced_train['Family_Hist_4']+reduced_train['Family_Hist_5'])

# %%
##  Medical History Total
reduced_train['Med_Hist_Total']=(reduced_train['Medical_History_1']+reduced_train['Medical_History_4']+reduced_train['Medical_History_5']+reduced_train['Medical_History_6']+reduced_train['Medical_History_8']+reduced_train['Medical_History_9']+reduced_train['Medical_History_10']+
                          reduced_train['Medical_History_11']+reduced_train['Medical_History_12']+reduced_train['Medical_History_13']+reduced_train['Medical_History_14']+reduced_train['Medical_History_15']+reduced_train['Medical_History_16']+reduced_train['Medical_History_17']+reduced_train['Medical_History_18']+reduced_train['Medical_History_19']+reduced_train['Medical_History_20']+
                          reduced_train['Medical_History_21']+reduced_train['Medical_History_22']+reduced_train['Medical_History_23']+reduced_train['Medical_History_27']+reduced_train['Medical_History_28']+reduced_train['Medical_History_29']+reduced_train['Medical_History_30']+
                          reduced_train['Medical_History_31']+reduced_train['Medical_History_33']+reduced_train['Medical_History_34']+reduced_train['Medical_History_35']+reduced_train['Medical_History_37']+reduced_train['Medical_History_38']+reduced_train['Medical_History_39']+reduced_train['Medical_History_40']+
                          reduced_train['Medical_History_41'])

# %%
## Medical Keyword Total
reduced_train['Med_Key_Total']=(reduced_train['Medical_Keyword_1']+reduced_train['Medical_Keyword_3']+reduced_train['Medical_Keyword_4']+reduced_train['Medical_Keyword_9']+reduced_train['Medical_Keyword_10']+
                         reduced_train['Medical_Keyword_12']+reduced_train['Medical_Keyword_13']+reduced_train['Medical_Keyword_15']+reduced_train['Medical_Keyword_16']+reduced_train['Medical_Keyword_18']+reduced_train['Medical_Keyword_19']+
                         reduced_train['Medical_Keyword_22']+reduced_train['Medical_Keyword_23']+reduced_train['Medical_Keyword_24']+reduced_train['Medical_Keyword_25']+reduced_train['Medical_Keyword_27']+
                         reduced_train['Medical_Keyword_31']+reduced_train['Medical_Keyword_33']+reduced_train['Medical_Keyword_34']+reduced_train['Medical_Keyword_35']+reduced_train['Medical_Keyword_36']+reduced_train['Medical_Keyword_37']+reduced_train['Medical_Keyword_38']+reduced_train['Medical_Keyword_40']+
                         reduced_train['Medical_Keyword_42']+reduced_train['Medical_Keyword_43']+reduced_train['Medical_Keyword_46']+reduced_train['Medical_Keyword_47']+reduced_train['Medical_Keyword_48'])

# %% [markdown]
# ## Look at Correlation values of new features

# %%
corr_matrix=reduced_train[['Response', 'Product_Total', 'Employment_Total', 'Insured_Total', 'Family_Hist_Total', 'Med_Hist_Total', 'Med_Key_Total']].corr()
corr_matrix['Response'].sort_values(ascending=False)
# Out:
# Response             1.000000
# Employment_Total     0.074374
# Insured_Total        0.056976
# Family_Hist_Total    0.041256
# Med_Hist_Total      -0.048810
# Product_Total       -0.059931
# Med_Key_Total       -0.346505
# Name: Response, dtype: float64

# %%
reduced_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59381 entries, 0 to 59380
# Columns: 101 entries, Product_Info_3 to Med_Key_Total
# dtypes: float64(17), int64(74), uint8(10)
# memory usage: 41.8 MB

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
train_X=reduced_train.drop('Response', axis=1)
train_y=reduced_train['Response']

# %%
Z_GB=GradientBoostingClassifier(n_estimators=300, subsample=0.8)

Z_GB.fit(train_X, train_y)
Z_GB.score(train_X, train_y)
# Out:
# 0.6164429699735605

# %% [markdown]
# ## Bring in Test Data

# %%
test_data=pd.read_csv('../Data/test.csv')

# %%
test_data.head(2)
# Out:
#    Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0   1               1             D3              26        0.487179
# 1   3               1             A2              26        0.076923
#
#    Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  \
# 0               2               3               1  0.611940  0.781818
# 1               2               3               1  0.626866  0.727273
#
#          Wt       BMI  Employment_Info_1  Employment_Info_2  \
# 0  0.338912  0.472262               0.15                  3
# 1  0.311715  0.484984               0.00                  1
#
#    Employment_Info_3  Employment_Info_4  Employment_Info_5  Employment_Info_6  \
# 0                  1               0.00                  2                0.5
# 1                  3               0.07                  2                0.2
#
#    InsuredInfo_1  InsuredInfo_2  InsuredInfo_3  InsuredInfo_4  InsuredInfo_5  \
# ...

# %%
## Put aside ID's for submission
test_IDs=test_data['Id']

# %% [markdown]
# #### get dummies

# %%
test_dummy_data=pd.get_dummies(test_data)

# %% [markdown]
# #### Fill NaN's with 0

# %%
test_dummy_data.fillna(0, inplace=True)

# %%
## Drop less than 3% correlation

reduced_test=test_dummy_data.drop(['Medical_History_7', 'InsuredInfo_4', 'Medical_History_3', 'Product_Info_2_A3',
                            'Employment_Info_6', 'Product_Info_2_A4', 'Insurance_History_5', 'Medical_History_2',
                            'Product_Info_1', 'Product_Info_2_C4', 'Medical_Keyword_39', 'Medical_Keyword_6',
                            'Medical_Keyword_20', 'Insurance_History_8', 'Insurance_History_3', 'Medical_Keyword_45',
                            'Medical_Keyword_8', 'Insurance_History_1', 'Medical_History_26', 'Insurance_History_4',
                            'Medical_History_25', 'Product_Info_2_C3', 'Medical_History_36', 'Product_Info_5',
                            'Medical_History_32', 'Product_Info_7', 'Insurance_History_9', 'Medical_Keyword_17',
                            'Insurance_History_7', 'Medical_Keyword_32', 'Medical_Keyword_41', 'Product_Info_2_B1',
                            'InsuredInfo_3', 'Product_Info_2_C2', 'Medical_Keyword_26', 'Medical_Keyword_2',
                            'Product_Info_2_A2', 'Product_Info_2_C1', 'Medical_Keyword_5', 'Medical_Keyword_29',
                            'Medical_Keyword_44', 'Medical_Keyword_7', 'Medical_Keyword_14', 'Employment_Info_4',
                            'Medical_Keyword_21', 'Medical_Keyword_30', 'Medical_Keyword_11', 'Medical_Keyword_28',
                            'Product_Info_2_D3', 'Medical_History_24'], axis=1)

# %%
### Add newly engineered columns

# %%
## Product total
reduced_test['Product_Total']=(reduced_test['Product_Info_3']+reduced_test["Product_Info_4"]+reduced_test["Product_Info_6"])

# %%
##  Employment Total
reduced_test['Employment_Total']=(reduced_test['Employment_Info_1']+reduced_test['Employment_Info_2']+reduced_test['Employment_Info_3']
                            +reduced_test['Employment_Info_5'])

# %%
##  Insured Total
reduced_test['Insured_Total']=(reduced_test['InsuredInfo_1']+reduced_test['InsuredInfo_2']+reduced_test['InsuredInfo_5']+reduced_test['InsuredInfo_6']+reduced_test['InsuredInfo_7'])

# %%
## Family Total
reduced_test['Family_Hist_Total']=(reduced_test['Family_Hist_1']+reduced_test['Family_Hist_2']+reduced_test['Family_Hist_3']+
                             reduced_test['Family_Hist_4']+reduced_test['Family_Hist_5'])

# %%
##  Medical History Total
reduced_test['Med_Hist_Total']=(reduced_test['Medical_History_1']+reduced_test['Medical_History_4']+reduced_test['Medical_History_5']+reduced_test['Medical_History_6']+reduced_test['Medical_History_8']+reduced_test['Medical_History_9']+reduced_test['Medical_History_10']+
                          reduced_test['Medical_History_11']+reduced_test['Medical_History_12']+reduced_test['Medical_History_13']+reduced_test['Medical_History_14']+reduced_test['Medical_History_15']+reduced_test['Medical_History_16']+reduced_test['Medical_History_17']+reduced_test['Medical_History_18']+reduced_test['Medical_History_19']+reduced_test['Medical_History_20']+
                          reduced_test['Medical_History_21']+reduced_test['Medical_History_22']+reduced_test['Medical_History_23']+reduced_test['Medical_History_27']+reduced_test['Medical_History_28']+reduced_test['Medical_History_29']+reduced_test['Medical_History_30']+
                          reduced_test['Medical_History_31']+reduced_test['Medical_History_33']+reduced_test['Medical_History_34']+reduced_test['Medical_History_35']+reduced_test['Medical_History_37']+reduced_test['Medical_History_38']+reduced_test['Medical_History_39']+reduced_test['Medical_History_40']+
                          reduced_test['Medical_History_41'])

# %%
## Medical Keyword Total
reduced_test['Med_Key_Total']=(reduced_test['Medical_Keyword_1']+reduced_test['Medical_Keyword_3']+reduced_test['Medical_Keyword_4']+reduced_test['Medical_Keyword_9']+reduced_test['Medical_Keyword_10']+
                         reduced_test['Medical_Keyword_12']+reduced_test['Medical_Keyword_13']+reduced_test['Medical_Keyword_15']+reduced_test['Medical_Keyword_16']+reduced_test['Medical_Keyword_18']+reduced_test['Medical_Keyword_19']+
                         reduced_test['Medical_Keyword_22']+reduced_test['Medical_Keyword_23']+reduced_test['Medical_Keyword_24']+reduced_test['Medical_Keyword_25']+reduced_test['Medical_Keyword_27']+
                         reduced_test['Medical_Keyword_31']+reduced_test['Medical_Keyword_33']+reduced_test['Medical_Keyword_34']+reduced_test['Medical_Keyword_35']+reduced_test['Medical_Keyword_36']+reduced_test['Medical_Keyword_37']+reduced_test['Medical_Keyword_38']+reduced_test['Medical_Keyword_40']+
                         reduced_test['Medical_Keyword_42']+reduced_test['Medical_Keyword_43']+reduced_test['Medical_Keyword_46']+reduced_test['Medical_Keyword_47']+reduced_test['Medical_Keyword_48'])

# %%
reduced_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19765 entries, 0 to 19764
# Columns: 101 entries, Id to Med_Key_Total
# dtypes: float64(17), int64(74), uint8(10)
# memory usage: 13.9 MB

# %% [markdown]
# ### Make Predictions

# %%
test_X=reduced_test.drop('Id', axis=1)

# %%
predictions=Z_GB.predict(test_X)

# %%
Test_Submission=pd.DataFrame({
    'Id': test_IDs,
    'Response': predictions
})

# %%
Test_Submission.Response.hist()

# %%
Test_Submission.to_csv(r'../Submissions/Z_GB_Submission4.csv', index=False, header=True)

# %%
data.Response.hist()
