# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('../Data/train.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59381 entries, 0 to 59380
# Columns: 128 entries, Id to Response
# dtypes: float64(18), int64(109), object(1)
# memory usage: 58.0+ MB

# %%
pd.set_option('display.max_columns', None)
data.head(3)
# Out:
#    Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0   2               1             D3              10        0.076923
# 1   5               1             A1              26        0.076923
# 2   6               1             E1              26        0.076923
#
#    Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  \
# 0               2               1               1  0.641791  0.581818
# 1               2               3               1  0.059701  0.600000
# 2               2               3               1  0.029851  0.745455
#
#          Wt       BMI  Employment_Info_1  Employment_Info_2  \
# 0  0.148536  0.323008              0.028                 12
# 1  0.131799  0.272288              0.000                  1
# 2  0.288703  0.428780              0.030                  9
#
#    Employment_Info_3  Employment_Info_4  Employment_Info_5  Employment_Info_6  \
# 0                  1                0.0                  3                NaN
# ...

# %%
train_data=pd.get_dummies(data)

# %%
train_data.drop("Id", axis=1, inplace=True)
train_data.head(2)
# Out:
#    Product_Info_1  Product_Info_3  Product_Info_4  Product_Info_5  \
# 0               1              10        0.076923               2
# 1               1              26        0.076923               2
#
#    Product_Info_6  Product_Info_7   Ins_Age        Ht        Wt       BMI  \
# 0               1               1  0.641791  0.581818  0.148536  0.323008
# 1               3               1  0.059701  0.600000  0.131799  0.272288
#
#    Employment_Info_1  Employment_Info_2  Employment_Info_3  Employment_Info_4  \
# 0              0.028                 12                  1                0.0
# 1              0.000                  1                  3                0.0
#
#    Employment_Info_5  Employment_Info_6  InsuredInfo_1  InsuredInfo_2  \
# 0                  3                NaN              1              2
# 1                  2             0.0018              1              2
#
#    InsuredInfo_3  InsuredInfo_4  InsuredInfo_5  InsuredInfo_6  InsuredInfo_7  \
# ...

# %% [markdown]
# ## Null Values

# %%
pd.set_option('display.max_rows', None)
train_data.isnull().sum()
# Out:
# Product_Info_1             0
# Product_Info_3             0
# Product_Info_4             0
# Product_Info_5             0
# Product_Info_6             0
# Product_Info_7             0
# Ins_Age                    0
# Ht                         0
# Wt                         0
# BMI                        0
# Employment_Info_1         19
# Employment_Info_2          0
# Employment_Info_3          0
# Employment_Info_4       6779
# Employment_Info_5          0
# Employment_Info_6      10854
# InsuredInfo_1              0
# InsuredInfo_2              0
# InsuredInfo_3              0
# InsuredInfo_4              0
# InsuredInfo_5              0
# InsuredInfo_6              0
# InsuredInfo_7              0
# Insurance_History_1        0
# Insurance_History_2        0
# Insurance_History_3        0
# Insurance_History_4        0
# Insurance_History_5    25396
# Insurance_History_7        0
# Insurance_History_8        0
# Insurance_History_9        0
# Family_Hist_1              0
# ...

# %% [markdown]
# ## new dataframe to fill NaN's with 0's

# %%
Z_train=train_data.copy()

# %%
# def fill_median(column):
#     median=column.median()
#     column.fillna(median, inplace=True)

# %%
Z_train.fillna(0, inplace=True)

# %%
Z_train.isnull().sum()[:3]
# Out:
# Product_Info_1    0
# Product_Info_3    0
# Product_Info_4    0
# dtype: int64

# %% [markdown]
# ## Engineer new columns

# %%
Z_train.head(1)
# Out:
#    Product_Info_1  Product_Info_3  Product_Info_4  Product_Info_5  \
# 0               1              10        0.076923               2
#
#    Product_Info_6  Product_Info_7   Ins_Age        Ht        Wt       BMI  \
# 0               1               1  0.641791  0.581818  0.148536  0.323008
#
#    Employment_Info_1  Employment_Info_2  Employment_Info_3  Employment_Info_4  \
# 0              0.028                 12                  1                0.0
#
#    Employment_Info_5  Employment_Info_6  InsuredInfo_1  InsuredInfo_2  \
# 0                  3                0.0              1              2
#
#    InsuredInfo_3  InsuredInfo_4  InsuredInfo_5  InsuredInfo_6  InsuredInfo_7  \
# 0              6              3              1              2              1
#
#    Insurance_History_1  Insurance_History_2  Insurance_History_3  \
# 0                    1                    1                    3
#
#    Insurance_History_4  Insurance_History_5  Insurance_History_7  \
# ...

# %%
## Product total
Z_train['Product_Total']=(Z_train['Product_Info_1']+Z_train['Product_Info_3']+Z_train["Product_Info_4"]+Z_train["Product_Info_5"]
                          +Z_train['Product_Info_6']+Z_train['Product_Info_7'])

# %%
##  Employment Total
Z_train['Employment_Total']=(Z_train['Employment_Info_1']+Z_train['Employment_Info_2']+Z_train['Employment_Info_3']
                            +Z_train['Employment_Info_4']+Z_train['Employment_Info_5']+Z_train['Employment_Info_6'])

# %%
##  Insured Total
Z_train['Insured_Total']=(Z_train['InsuredInfo_1']+Z_train['InsuredInfo_2']+Z_train['InsuredInfo_3']
                         +Z_train['InsuredInfo_4']+Z_train['InsuredInfo_5']+Z_train['InsuredInfo_6']+Z_train['InsuredInfo_7'])

# %%
##  Insurance History Total
Z_train['InsHistTotal']=(Z_train['Insurance_History_1']+Z_train['Insurance_History_2']+Z_train['Insurance_History_3']
                        +Z_train['Insurance_History_4']+Z_train['Insurance_History_5']+Z_train['Insurance_History_7']
                        +Z_train['Insurance_History_8']+Z_train['Insurance_History_9'])

# %%
## Family Total
Z_train['Family_Hist_Total']=(Z_train['Family_Hist_1']+Z_train['Family_Hist_2']+Z_train['Family_Hist_3']+
                             Z_train['Family_Hist_4']+Z_train['Family_Hist_5'])

# %%
##  Medical History Total
Z_train['Med_Hist_Total']=(Z_train['Medical_History_1']+Z_train['Medical_History_2']+Z_train['Medical_History_3']+Z_train['Medical_History_4']+Z_train['Medical_History_5']+Z_train['Medical_History_6']+Z_train['Medical_History_7']+Z_train['Medical_History_8']+Z_train['Medical_History_9']+Z_train['Medical_History_10']+
                          Z_train['Medical_History_11']+Z_train['Medical_History_12']+Z_train['Medical_History_13']+Z_train['Medical_History_14']+Z_train['Medical_History_15']+Z_train['Medical_History_16']+Z_train['Medical_History_17']+Z_train['Medical_History_18']+Z_train['Medical_History_19']+Z_train['Medical_History_20']+
                          Z_train['Medical_History_21']+Z_train['Medical_History_22']+Z_train['Medical_History_23']+Z_train['Medical_History_24']+Z_train['Medical_History_25']+Z_train['Medical_History_26']+Z_train['Medical_History_27']+Z_train['Medical_History_28']+Z_train['Medical_History_29']+Z_train['Medical_History_30']+
                          Z_train['Medical_History_31']+Z_train['Medical_History_32']+Z_train['Medical_History_33']+Z_train['Medical_History_34']+Z_train['Medical_History_35']+Z_train['Medical_History_36']+Z_train['Medical_History_37']+Z_train['Medical_History_38']+Z_train['Medical_History_39']+Z_train['Medical_History_40']+
                          Z_train['Medical_History_41'])

# %%
## Medical Keyword Total
Z_train['Med_Key_Total']=(Z_train['Medical_Keyword_1']+Z_train['Medical_Keyword_2']+Z_train['Medical_Keyword_3']+Z_train['Medical_Keyword_4']+Z_train['Medical_Keyword_5']+Z_train['Medical_Keyword_6']+Z_train['Medical_Keyword_7']+Z_train['Medical_Keyword_8']+Z_train['Medical_Keyword_9']+Z_train['Medical_Keyword_10']+
                         Z_train['Medical_Keyword_11']+Z_train['Medical_Keyword_12']+Z_train['Medical_Keyword_13']+Z_train['Medical_Keyword_14']+Z_train['Medical_Keyword_15']+Z_train['Medical_Keyword_16']+Z_train['Medical_Keyword_17']+Z_train['Medical_Keyword_18']+Z_train['Medical_Keyword_19']+Z_train['Medical_Keyword_20']+
                         Z_train['Medical_Keyword_21']+Z_train['Medical_Keyword_22']+Z_train['Medical_Keyword_23']+Z_train['Medical_Keyword_24']+Z_train['Medical_Keyword_25']+Z_train['Medical_Keyword_26']+Z_train['Medical_Keyword_27']+Z_train['Medical_Keyword_28']+Z_train['Medical_Keyword_29']+Z_train['Medical_Keyword_30']+
                         Z_train['Medical_Keyword_31']+Z_train['Medical_Keyword_32']+Z_train['Medical_Keyword_33']+Z_train['Medical_Keyword_34']+Z_train['Medical_Keyword_35']+Z_train['Medical_Keyword_36']+Z_train['Medical_Keyword_37']+Z_train['Medical_Keyword_38']+Z_train['Medical_Keyword_39']+Z_train['Medical_Keyword_40']+
                         Z_train['Medical_Keyword_41']+Z_train['Medical_Keyword_42']+Z_train['Medical_Keyword_43']+Z_train['Medical_Keyword_44']+Z_train['Medical_Keyword_45']+Z_train['Medical_Keyword_46']+Z_train['Medical_Keyword_47']+Z_train['Medical_Keyword_48'])

# %% [markdown]
# ## Look at Correlation values of new features

# %%
corr_matrix=Z_train[['Response', 'Product_Total', 'Employment_Total', 'Insured_Total', 'InsHistTotal', 'Family_Hist_Total', 'Med_Hist_Total', 'Med_Key_Total']].corr()
corr_matrix['Response']
# Out:
# Response             1.000000
# Product_Total       -0.059496
# Employment_Total     0.075724
# Insured_Total        0.008425
# InsHistTotal        -0.018306
# Family_Hist_Total    0.041256
# Med_Hist_Total      -0.007810
# Med_Key_Total       -0.314204
# Name: Response, dtype: float64

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
train_X=Z_train.drop('Response', axis=1)
train_y=Z_train['Response']

# %%
Z_GB=GradientBoostingClassifier(n_estimators=250, subsample=0.7)

Z_GB.fit(train_X, train_y)
Z_GB.score(train_X, train_y)

## 0.619  subsample=0.8
# Out:
# 0.6198278910762702

# %% [markdown]
# ## Bring in Test Data

# %%
test_data=pd.read_csv('../Data/test.csv')

# %%
test_data.head(2)
# Out:
#    Id  Product_Info_1 Product_Info_2  Product_Info_3  Product_Info_4  \
# 0   1               1             D3              26        0.487179
# 1   3               1             A2              26        0.076923
#
#    Product_Info_5  Product_Info_6  Product_Info_7   Ins_Age        Ht  \
# 0               2               3               1  0.611940  0.781818
# 1               2               3               1  0.626866  0.727273
#
#          Wt       BMI  Employment_Info_1  Employment_Info_2  \
# 0  0.338912  0.472262               0.15                  3
# 1  0.311715  0.484984               0.00                  1
#
#    Employment_Info_3  Employment_Info_4  Employment_Info_5  Employment_Info_6  \
# 0                  1               0.00                  2                0.5
# 1                  3               0.07                  2                0.2
#
#    InsuredInfo_1  InsuredInfo_2  InsuredInfo_3  InsuredInfo_4  InsuredInfo_5  \
# ...

# %%
## Put aside ID's for submission
test_IDs=test_data['Id']

# %% [markdown]
# #### get dummies

# %%
test_dummy_data=pd.get_dummies(test_data)

# %% [markdown]
# #### Fill NaN's with 0

# %%
test_dummy_data.fillna(0, inplace=True)

# %% [markdown]
# ### Add newly engineered columns

# %%
## Product total
test_dummy_data['Product_Total']=(test_dummy_data['Product_Info_1']+test_dummy_data['Product_Info_3']+test_dummy_data["Product_Info_4"]+test_dummy_data["Product_Info_5"]
                          +test_dummy_data['Product_Info_6']+test_dummy_data['Product_Info_7'])

# %%
##  Employment Total
test_dummy_data['Employment_Total']=(test_dummy_data['Employment_Info_1']+test_dummy_data['Employment_Info_2']+test_dummy_data['Employment_Info_3']
                            +test_dummy_data['Employment_Info_4']+test_dummy_data['Employment_Info_5']+test_dummy_data['Employment_Info_6'])

# %%
##  Insured Total
test_dummy_data['Insured_Total']=(test_dummy_data['InsuredInfo_1']+test_dummy_data['InsuredInfo_2']+test_dummy_data['InsuredInfo_3']
                         +test_dummy_data['InsuredInfo_4']+test_dummy_data['InsuredInfo_5']+test_dummy_data['InsuredInfo_6']+test_dummy_data['InsuredInfo_7'])

# %%
##  Insurance History Total
test_dummy_data['InsHistTotal']=(test_dummy_data['Insurance_History_1']+test_dummy_data['Insurance_History_2']+test_dummy_data['Insurance_History_3']
                        +test_dummy_data['Insurance_History_4']+test_dummy_data['Insurance_History_5']+test_dummy_data['Insurance_History_7']
                        +test_dummy_data['Insurance_History_8']+test_dummy_data['Insurance_History_9'])

# %%
## Family Total
test_dummy_data['Family_Hist_Total']=(test_dummy_data['Family_Hist_1']+test_dummy_data['Family_Hist_2']+test_dummy_data['Family_Hist_3']+
                             test_dummy_data['Family_Hist_4']+test_dummy_data['Family_Hist_5'])

# %%
##  Medical History Total
test_dummy_data['Med_Hist_Total']=(test_dummy_data['Medical_History_1']+test_dummy_data['Medical_History_2']+test_dummy_data['Medical_History_3']+test_dummy_data['Medical_History_4']+test_dummy_data['Medical_History_5']+test_dummy_data['Medical_History_6']+test_dummy_data['Medical_History_7']+test_dummy_data['Medical_History_8']+test_dummy_data['Medical_History_9']+test_dummy_data['Medical_History_10']+
                          test_dummy_data['Medical_History_11']+test_dummy_data['Medical_History_12']+test_dummy_data['Medical_History_13']+test_dummy_data['Medical_History_14']+test_dummy_data['Medical_History_15']+test_dummy_data['Medical_History_16']+test_dummy_data['Medical_History_17']+test_dummy_data['Medical_History_18']+test_dummy_data['Medical_History_19']+test_dummy_data['Medical_History_20']+
                          test_dummy_data['Medical_History_21']+test_dummy_data['Medical_History_22']+test_dummy_data['Medical_History_23']+test_dummy_data['Medical_History_24']+test_dummy_data['Medical_History_25']+test_dummy_data['Medical_History_26']+test_dummy_data['Medical_History_27']+test_dummy_data['Medical_History_28']+test_dummy_data['Medical_History_29']+test_dummy_data['Medical_History_30']+
                          test_dummy_data['Medical_History_31']+test_dummy_data['Medical_History_32']+test_dummy_data['Medical_History_33']+test_dummy_data['Medical_History_34']+test_dummy_data['Medical_History_35']+test_dummy_data['Medical_History_36']+test_dummy_data['Medical_History_37']+test_dummy_data['Medical_History_38']+test_dummy_data['Medical_History_39']+test_dummy_data['Medical_History_40']+
                          test_dummy_data['Medical_History_41'])

# %%
## Medical Keyword Total
test_dummy_data['Med_Key_Total']=(test_dummy_data['Medical_Keyword_1']+test_dummy_data['Medical_Keyword_2']+test_dummy_data['Medical_Keyword_3']+test_dummy_data['Medical_Keyword_4']+test_dummy_data['Medical_Keyword_5']+test_dummy_data['Medical_Keyword_6']+test_dummy_data['Medical_Keyword_7']+test_dummy_data['Medical_Keyword_8']+test_dummy_data['Medical_Keyword_9']+test_dummy_data['Medical_Keyword_10']+
                         test_dummy_data['Medical_Keyword_11']+test_dummy_data['Medical_Keyword_12']+test_dummy_data['Medical_Keyword_13']+test_dummy_data['Medical_Keyword_14']+test_dummy_data['Medical_Keyword_15']+test_dummy_data['Medical_Keyword_16']+test_dummy_data['Medical_Keyword_17']+test_dummy_data['Medical_Keyword_18']+test_dummy_data['Medical_Keyword_19']+test_dummy_data['Medical_Keyword_20']+
                         test_dummy_data['Medical_Keyword_21']+test_dummy_data['Medical_Keyword_22']+test_dummy_data['Medical_Keyword_23']+test_dummy_data['Medical_Keyword_24']+test_dummy_data['Medical_Keyword_25']+test_dummy_data['Medical_Keyword_26']+test_dummy_data['Medical_Keyword_27']+test_dummy_data['Medical_Keyword_28']+test_dummy_data['Medical_Keyword_29']+test_dummy_data['Medical_Keyword_30']+
                         test_dummy_data['Medical_Keyword_31']+test_dummy_data['Medical_Keyword_32']+test_dummy_data['Medical_Keyword_33']+test_dummy_data['Medical_Keyword_34']+test_dummy_data['Medical_Keyword_35']+test_dummy_data['Medical_Keyword_36']+test_dummy_data['Medical_Keyword_37']+test_dummy_data['Medical_Keyword_38']+test_dummy_data['Medical_Keyword_39']+test_dummy_data['Medical_Keyword_40']+
                         test_dummy_data['Medical_Keyword_41']+test_dummy_data['Medical_Keyword_42']+test_dummy_data['Medical_Keyword_43']+test_dummy_data['Medical_Keyword_44']+test_dummy_data['Medical_Keyword_45']+test_dummy_data['Medical_Keyword_46']+test_dummy_data['Medical_Keyword_47']+test_dummy_data['Medical_Keyword_48'])

# %% [markdown]
# ### Make Predictions

# %%
test_X=test_dummy_data.drop('Id', axis=1)

# %%
predictions=Z_GB.predict(test_X)

# %%
Test_Submission=pd.DataFrame({
    'Id': test_IDs,
    'Response': predictions
})

# %%
Test_Submission.Response.hist()

# %%
Test_Submission.to_csv(r'../Submissions/Z_GB_Submission2.csv', index=False, header=True)

# %%
data.Response.hist()

# %% [markdown]
# ## XGBOOST

# %%
from xgboost import XGBClassifier

# %%
XG1=XGBClassifier()

# %%
XG1.fit(train_X, train_y)
# Out:
# C:\Users\chris\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:39:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
# ...

# %%
XG1.score(train_X, train_y)
# Out:
# 0.7209039928596689

# %% [markdown]
# ### Predictions

# %%
XGPreds=XG1.predict(test_X)

# %%
Test_Submission=pd.DataFrame({
    'Id': test_IDs,
    'Response': XGPreds
})

# %%
Test_Submission.Response.hist()

# %%
Test_Submission.to_csv(r'../Submissions/XGB_Submission1.csv', index=False, header=True)

# %%
data.Response.hist()
